# %%
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import GridSearchCV

from sklearn.tree import export_graphviz

# %%
df = pd.read_csv("../CSV/CamposNovosPOWER.csv", delimiter=',')

# %%
df.head()
# Out:
#         LAT       LON  YEAR  DOY  PRECTOT  WS2M  T2MDEW   RH2M  T2M_MAX  \
# 0 -27.38339 -51.21929  1984    1     8.63  1.14   19.58  83.16    26.95
# 1 -27.38339 -51.21929  1984    2     7.18  1.14   19.45  83.54    26.46
# 2 -27.38339 -51.21929  1984    3    12.46  1.25   19.27  91.43    23.27
# 3 -27.38339 -51.21929  1984    4     9.24  1.53   19.35  85.57    26.84
# 4 -27.38339 -51.21929  1984    5     2.06  1.86   20.11  86.48    27.28
#
#    T2M_MIN    T2M  ALLSKY_TOA_SW_DWN  ALLSKY_SFC_SW_DWN     TS
# 0    18.77  22.58              43.56              20.20  22.60
# 1    18.16  22.38              43.52              24.34  22.46
# 2    18.32  20.71              43.52              12.31  20.57
# 3    17.54  21.91              43.49              23.62  22.07
# 4    18.38  22.49              43.45              20.92  22.65

# %%
Mai15OY = 31
#if df.LAT[0]<0 :
#    Mai15OY = 365-31-30-31
#Mai15OY

# %%
df.drop(['LAT', 'LON'], axis=1)
# Out:
#        YEAR  DOY  PRECTOT    WS2M  T2MDEW    RH2M  T2M_MAX  T2M_MIN    T2M  \
# 0      1984    1     8.63    1.14   19.58   83.16    26.95    18.77  22.58
# 1      1984    2     7.18    1.14   19.45   83.54    26.46    18.16  22.38
# 2      1984    3    12.46    1.25   19.27   91.43    23.27    18.32  20.71
# 3      1984    4     9.24    1.53   19.35   85.57    26.84    17.54  21.91
# 4      1984    5     2.06    1.86   20.11   86.48    27.28    18.38  22.49
# ...     ...  ...      ...     ...     ...     ...      ...      ...    ...
# 13562  2021   48     0.20    1.23   15.03   79.42    24.32    14.21  18.62
# 13563  2021   49     0.12    1.22   13.66   77.12    23.68    11.89  17.67
# 13564  2021   50   -99.00 -999.00  -99.00 -999.00   -99.00   -99.00 -99.00
# 13565  2021   51   -99.00 -999.00  -99.00 -999.00   -99.00   -99.00 -99.00
# 13566  2021   52   -99.00 -999.00  -99.00 -999.00   -99.00   -99.00 -99.00
#
#        ALLSKY_TOA_SW_DWN  ALLSKY_SFC_SW_DWN     TS
# 0                  43.56              20.20  22.60
# 1                  43.52              24.34  22.46
# 2                  43.52              12.31  20.57
# 3                  43.49              23.62  22.07
# 4                  43.45              20.92  22.65
# ...                  ...                ...    ...
# 13562             -99.00             -99.00  18.88
# 13563             -99.00             -99.00  17.72
# 13564             -99.00             -99.00 -99.00
# 13565             -99.00             -99.00 -99.00
# 13566             -99.00             -99.00 -99.00
#
# [13567 rows x 12 columns]

# %% [markdown]
# # FRANCE :
# Pour atteindre sa maturité le soja doit cumuler en sec 1 400 °C jour (variété 000) à 1 440 °C jour (variété 00) auquel il faut rajouter une semaine pour obtenir la date de récolte. En 2017 la carte ci-dessous nous montre que pour des levées du 15 mai on peut espérer récolter sur septembre dans la plupart des secteurs.

# %% [markdown]
# Les levées plus tardives devront certainement patienter sur début octobre. Après la mi-octobre, avec la réduction de la durée du jour, l’humidité et la pluviométrie, il est difficile de descendre en dessous de 18-20 % d’humidité. La qualité des graines risque d’être rapidement altérée par le développement de moisissures (graines colorées en noir à la surface du grain). Si la récolte s’annonce tardive, il est donc conseillé de récolter, même si l’humidité atteint 20 à 25 %. Dans ce cas, livrer la récolte le plus rapidement possible car les graines ne se conservent pas à plus de 14 % d’humidité. A noter qu’il n’y a plus aucun produit autorisé pour défaner chimiquement le soja.

# %%
# CUT 2021
df = df[df.YEAR!=2021]
df
# Out:
#             LAT       LON  YEAR  DOY  PRECTOT  WS2M  T2MDEW   RH2M  T2M_MAX  \
# 0     -27.38339 -51.21929  1984    1     8.63  1.14   19.58  83.16    26.95
# 1     -27.38339 -51.21929  1984    2     7.18  1.14   19.45  83.54    26.46
# 2     -27.38339 -51.21929  1984    3    12.46  1.25   19.27  91.43    23.27
# 3     -27.38339 -51.21929  1984    4     9.24  1.53   19.35  85.57    26.84
# 4     -27.38339 -51.21929  1984    5     2.06  1.86   20.11  86.48    27.28
# ...         ...       ...   ...  ...      ...   ...     ...    ...      ...
# 13510 -27.38339 -51.21929  2020  362     0.81  1.49   15.50  67.63    28.13
# 13511 -27.38339 -51.21929  2020  363     5.21  1.34   16.77  67.65    29.17
# 13512 -27.38339 -51.21929  2020  364    11.91  1.30   18.55  78.21    28.03
# 13513 -27.38339 -51.21929  2020  365     5.27  1.57   19.00  76.08    29.31
# 13514 -27.38339 -51.21929  2020  366    10.14  1.57   20.23  85.53    27.51
#
#        T2M_MIN    T2M  ALLSKY_TOA_SW_DWN  ALLSKY_SFC_SW_DWN     TS
# 0        18.77  22.58              43.56              20.20  22.60
# 1        18.16  22.38              43.52              24.34  22.46
# 2        18.32  20.71              43.52              12.31  20.57
# 3        17.54  21.91              43.49              23.62  22.07
# 4        18.38  22.49              43.45              20.92  22.65
# ...        ...    ...                ...                ...    ...
# 13510    15.94  21.64              43.50              25.37  22.52
# 13511    16.90  22.96              43.49              11.73  23.54
# 13512    18.00  22.47              43.47              20.16  22.50
# 13513    17.64  23.37              43.45              27.46  23.66
# 13514    19.27  22.77              43.43              22.39  22.90
#
# [13515 rows x 14 columns]

# %%
df_ = df[df.DOY>31]
df_ = df_[df_.DOY<181]
df_
# Out:
#             LAT       LON  YEAR  DOY  PRECTOT  WS2M  T2MDEW   RH2M  T2M_MAX  \
# 31    -27.38339 -51.21929  1984   32    13.35  1.05   19.11  85.63    26.78
# 32    -27.38339 -51.21929  1984   33     8.33  1.28   20.06  85.57    27.35
# 33    -27.38339 -51.21929  1984   34     1.22  0.89   19.67  81.58    28.20
# 34    -27.38339 -51.21929  1984   35     1.79  1.29   20.37  81.13    29.06
# 35    -27.38339 -51.21929  1984   36    10.55  1.37   20.70  86.31    27.78
# ...         ...       ...   ...  ...      ...   ...     ...    ...      ...
# 13324 -27.38339 -51.21929  2020  176     0.15  1.57   11.56  80.50    22.84
# 13325 -27.38339 -51.21929  2020  177    22.75  2.28   12.54  88.63    20.34
# 13326 -27.38339 -51.21929  2020  178     0.30  0.86    5.68  78.45    14.24
# 13327 -27.38339 -51.21929  2020  179     3.13  1.45    7.62  84.48    15.16
# 13328 -27.38339 -51.21929  2020  180     0.35  0.87    7.78  85.05    16.31
#
#        T2M_MIN    T2M  ALLSKY_TOA_SW_DWN  ALLSKY_SFC_SW_DWN     TS
# 31       17.48  21.65              41.54              11.84  21.75
# 32       18.50  22.61              41.44              22.82  22.48
# 33       17.71  23.00              41.33              28.01  22.99
# 34       19.13  23.81              41.22              27.36  23.74
# 35       19.86  23.10              41.11              21.13  23.04
# ...        ...    ...                ...                ...    ...
# 13324     8.99  14.86              19.87              13.43  14.48
# 13325     9.64  14.41              19.89               2.08  14.16
# 13326     5.94   9.21              19.91              11.56   9.62
# 13327     6.67  10.12              19.93               5.26  10.38
# 13328     6.93  10.18              19.96              10.90  10.52
#
# [5513 rows x 14 columns]

# %%
# La bibliothèque numpy offre plusieurs fonctions très utiles. Par exemple, elle nous permet de créer une nouvelle colonne dans notre
# dataframe si une condition est satisfaite

def imputeColumns(dataset):
    """ Pour chacune des colonnes du dataset,
        mise à jour des valeurs < par la moyenne de ses valeurs non nulles.
    """
    # liste des colonnes qui seront traitées
    columnsToImpute=['PRECTOT', 'WS2M', 'T2MDEW','RH2M', 'T2M_MAX', 'T2M_MIN' ,'T2M', 'ALLSKY_TOA_SW_DWN', 'ALLSKY_SFC_SW_DWN', 'TS']

    for c in columnsToImpute:
        avgOfCol=dataset[dataset[c]>=0][[c]].mean()
        dataset[c]=np.where(dataset[[c]]>=0,dataset[[c]],avgOfCol)

imputeColumns(df_)

# check that we've imputed the -99 values  
df_
# Out:
#             LAT       LON  YEAR  DOY  PRECTOT  WS2M  T2MDEW   RH2M  T2M_MAX  \
# 31    -27.38339 -51.21929  1984   32    13.35  1.05   19.11  85.63    26.78
# 32    -27.38339 -51.21929  1984   33     8.33  1.28   20.06  85.57    27.35
# 33    -27.38339 -51.21929  1984   34     1.22  0.89   19.67  81.58    28.20
# 34    -27.38339 -51.21929  1984   35     1.79  1.29   20.37  81.13    29.06
# 35    -27.38339 -51.21929  1984   36    10.55  1.37   20.70  86.31    27.78
# ...         ...       ...   ...  ...      ...   ...     ...    ...      ...
# 13324 -27.38339 -51.21929  2020  176     0.15  1.57   11.56  80.50    22.84
# 13325 -27.38339 -51.21929  2020  177    22.75  2.28   12.54  88.63    20.34
# 13326 -27.38339 -51.21929  2020  178     0.30  0.86    5.68  78.45    14.24
# 13327 -27.38339 -51.21929  2020  179     3.13  1.45    7.62  84.48    15.16
# 13328 -27.38339 -51.21929  2020  180     0.35  0.87    7.78  85.05    16.31
#
#        T2M_MIN    T2M  ALLSKY_TOA_SW_DWN  ALLSKY_SFC_SW_DWN     TS
# 31       17.48  21.65              41.54              11.84  21.75
# 32       18.50  22.61              41.44              22.82  22.48
# 33       17.71  23.00              41.33              28.01  22.99
# 34       19.13  23.81              41.22              27.36  23.74
# 35       19.86  23.10              41.11              21.13  23.04
# ...        ...    ...                ...                ...    ...
# 13324     8.99  14.86              19.87              13.43  14.48
# 13325     9.64  14.41              19.89               2.08  14.16
# 13326     5.94   9.21              19.91              11.56   9.62
# 13327     6.67  10.12              19.93               5.26  10.38
# 13328     6.93  10.18              19.96              10.90  10.52
#
# [5513 rows x 14 columns]

# %%
df_=df_.drop(columns=['LAT','LON', 'DOY'], axis =1 )

# %%
# %matplotlib inline

matrice_corr = df_.corr().round(1)
sns.heatmap(data=matrice_corr, annot=True)

# %%
#['T2M', 'ALLSKY_SFC_SW_DWN', 'T2MDEW', 'T2M_MIN', 'YEAR', 'RH2M', 'surface (ha)']

# %%
df_sojaSM = pd.read_csv("../CSV/mais_Campos_Novos_1974_2018.txt", sep="\t")
df_sojaSM.head()
# Out:
#    Annee  surface (ha)  Production (t)  Productivite (kg/ha)  \
# 0   1974         25000           53000                  2120
# 1   1975         25000           45000                  1800
# 2   1976         28000           42000                  1500
# 3   1977         30000           45000                  1500
# 4   1978         20000           22000                  1100
#
#    Productivite (sacs/ha)
# 0                    35.3
# 1                    30.0
# 2                    25.0
# 3                    25.0
# 4                    18.3

# %%
selection = df_sojaSM.Annee<1984
index2Remove = df_sojaSM[selection].index
df_sojaSM=df_sojaSM.drop(index2Remove)

# %%
X_VAL = df_[df_.YEAR==2019]

# %%
selection = df_.YEAR>2018
index2Remove = df_[selection].index
df_=df_.drop(index2Remove)

# %%
cmp = df_sojaSM.index[0]
for r in df_.index:
    if df_.YEAR[r] != df_sojaSM.Annee[cmp]:
        cmp = cmp+1
        
    if df_.YEAR[r] == df_sojaSM.Annee[cmp]:
        df_.at[r, 'Productivite (kg/ha)'] = df_sojaSM.at[cmp, 'Productivite (kg/ha)']
        df_.at[r, 'Production (t)'] = df_sojaSM.at[cmp, 'Production (t)']
        df_.at[r, 'surface (ha)'] = df_sojaSM.at[cmp, 'Production (t)']

# %%
df_.describe()
# Out:
#               YEAR      PRECTOT         WS2M       T2MDEW         RH2M  \
# count  5215.000000  5215.000000  5215.000000  5215.000000  5215.000000
# mean   2001.000000     4.777952     1.200224    14.034172    83.042382
# std      10.100473     9.280347     0.365946     4.254896     7.299357
# min    1984.000000     0.000000     0.420000     0.200000    41.220000
# 25%    1992.000000     0.040000     0.940000    11.510000    78.990000
# 50%    2001.000000     0.760000     1.140000    14.670000    83.700000
# 75%    2010.000000     5.180000     1.380000    17.400000    88.045000
# max    2018.000000   137.970000     3.110000    22.120000    99.590000
#
#            T2M_MAX      T2M_MIN          T2M  ALLSKY_TOA_SW_DWN  \
# count  5215.000000  5215.000000  5215.000000        5215.000000
# mean     22.565440    12.472982    16.932539          28.929177
# std       4.236816     4.388805     4.341950           7.294404
# min       4.360000     0.020000     1.050000          19.390000
# 25%      19.820000     9.580000    14.060000          21.650000
# 50%      23.290000    13.020000    17.740000          28.010000
# 75%      25.820000    15.940000    20.465000          35.770000
# max      34.540000    21.550000    26.260000          42.130000
#
#        ALLSKY_SFC_SW_DWN           TS  Productivite (kg/ha)  Production (t)  \
# count        5215.000000  5215.000000           5215.000000     5215.000000
# mean           14.811221    16.852311           5394.742857    92128.342857
# std             6.455613     4.472475           2891.435584    37946.845250
# min             0.400000     0.950000            950.000000    19200.000000
# 25%            10.470000    13.780000           3360.000000    64350.000000
# 50%            14.690000    17.740000           5100.000000    90000.000000
# 75%            19.330000    20.495000           7200.000000   120000.000000
# max            31.750000    27.760000          12000.000000   171600.000000
#
#         surface (ha)
# count    5215.000000
# mean    92128.342857
# std     37946.845250
# min     19200.000000
# 25%     64350.000000
# 50%     90000.000000
# 75%    120000.000000
# max    171600.000000

# %% [markdown]
# # Coefficient de Pearson
#
# Le coefficient de Pearson ou Pearson r est une mesure qui exprime à quel point deux variables sont linéairement corrélées. Il est égale au quotient de la covariance des deux variables et du produit des deux écarts-types

# %%
from scipy.stats import pearsonr
for c in df_.columns:
    coeff_pearson,_ = pearsonr(df_[c],df_['Productivite (kg/ha)'])
    print(c, "coefficient de Pearson = {}".format(coeff_pearson))
# Out:
# YEAR coefficient de Pearson = 0.911741055289873
# PRECTOT coefficient de Pearson = 0.0025708899094340956
# WS2M coefficient de Pearson = 0.020456375148901543
# T2MDEW coefficient de Pearson = 0.0453725428093543
# RH2M coefficient de Pearson = 0.10365330390454329
# T2M_MAX coefficient de Pearson = -0.024429762593242997
# T2M_MIN coefficient de Pearson = 0.033853116540367406
# T2M coefficient de Pearson = 0.009166786328190664
# ALLSKY_TOA_SW_DWN coefficient de Pearson = -0.004666615940603909
# ALLSKY_SFC_SW_DWN coefficient de Pearson = 0.01067109377116503
# TS coefficient de Pearson = 0.011640202909083922
# Productivite (kg/ha) coefficient de Pearson = 1.0
# Production (t) coefficient de Pearson = 0.55108942304974
# surface (ha) coefficient de Pearson = 0.55108942304974

# %% [markdown]
# Nous pouvons observer une forte corrélation

# %%
coeff_pearson,_ = pearsonr(df_sojaSM.Annee,df_sojaSM['Productivite (kg/ha)'])
print("coefficient de Pearson = {}".format(coeff_pearson))
# Out:
# coefficient de Pearson = 0.9117410552898727

# %%
 #PAS GÉNÉRIQUE !   
cmp = df_sojaSM.index[0]
firstYear = True
for r in df_.index:
    if firstYear :
        df_.at[r, 'Coeff_prod'] = 0 ##Année ref

    if df_.YEAR[r] != df_sojaSM.Annee[cmp]:
        cmp = cmp+1
        firstYear = False
    
    if df_.YEAR[r] == df_sojaSM.Annee[cmp] and firstYear == False:
        coef_prod = (df_sojaSM.at[cmp, 'Productivite (kg/ha)']/df_sojaSM.at[cmp-1, 'Productivite (kg/ha)'])
        df_.at[r, 'Coeff_prod'] = coef_prod


df_.describe()
# Out:
#               YEAR      PRECTOT         WS2M       T2MDEW         RH2M  \
# count  5215.000000  5215.000000  5215.000000  5215.000000  5215.000000
# mean   2001.000000     4.777952     1.200224    14.034172    83.042382
# std      10.100473     9.280347     0.365946     4.254896     7.299357
# min    1984.000000     0.000000     0.420000     0.200000    41.220000
# 25%    1992.000000     0.040000     0.940000    11.510000    78.990000
# 50%    2001.000000     0.760000     1.140000    14.670000    83.700000
# 75%    2010.000000     5.180000     1.380000    17.400000    88.045000
# max    2018.000000   137.970000     3.110000    22.120000    99.590000
#
#            T2M_MAX      T2M_MIN          T2M  ALLSKY_TOA_SW_DWN  \
# count  5215.000000  5215.000000  5215.000000        5215.000000
# mean     22.565440    12.472982    16.932539          28.929177
# std       4.236816     4.388805     4.341950           7.294404
# min       4.360000     0.020000     1.050000          19.390000
# 25%      19.820000     9.580000    14.060000          21.650000
# 50%      23.290000    13.020000    17.740000          28.010000
# 75%      25.820000    15.940000    20.465000          35.770000
# max      34.540000    21.550000    26.260000          42.130000
#
#        ALLSKY_SFC_SW_DWN           TS  Productivite (kg/ha)  Production (t)  \
# count        5215.000000  5215.000000           5215.000000     5215.000000
# mean           14.811221    16.852311           5394.742857    92128.342857
# std             6.455613     4.472475           2891.435584    37946.845250
# min             0.400000     0.950000            950.000000    19200.000000
# 25%            10.470000    13.780000           3360.000000    64350.000000
# 50%            14.690000    17.740000           5100.000000    90000.000000
# 75%            19.330000    20.495000           7200.000000   120000.000000
# max            31.750000    27.760000          12000.000000   171600.000000
#
#         surface (ha)   Coeff_prod
# count    5215.000000  5215.000000
# mean    92128.342857     1.092458
# std     37946.845250     0.568323
# min     19200.000000     0.000000
# 25%     64350.000000     0.914286
# 50%     90000.000000     1.052941
# 75%    120000.000000     1.176471
# max    171600.000000     3.868421

# %%
coeff_pearson,_ = pearsonr(df_.Coeff_prod,df_['Productivite (kg/ha)'])
print("coefficient de Pearson = {}".format(coeff_pearson))
#Les points tombent près de la ligne, ce qui indique une relation négative forte entre les variables. La relation est négative car lorsqu'une variable chute, l'autre variable chute aussi.
# Out:
# coefficient de Pearson = 0.1001649070317915

# %%
x = df_.YEAR
y = df_['Coeff_prod']

sns.jointplot(x=x, y=y, kind="hex", color="#4CB391")

# %% [markdown]
# Nous pouvons observer très clairement cette courbe que nous souhaitons désormais applatir

# %%
columnsNamesArr = ['YEAR']
df_features = df_[columnsNamesArr]
# définir la variable cible
df_labels = df_[['Coeff_prod']]

scale = StandardScaler()
#X_scaled = pd.DataFrame(scale.fit_transform(df_features))
#Y_scaled = pd.DataFrame(scale.fit_transform(df_[['Coeff_prod']]))
X_scaled = df_features
Y_scaled = df_[['Coeff_prod']]

X_train, X_test, y_train, y_test = train_test_split(X_scaled, Y_scaled, test_size=0.25, random_state=1)
3
from sklearn.ensemble import RandomForestRegressor

clf = RandomForestRegressor(max_depth=None, n_estimators=100)
clf.fit(X_train, y_train.values.ravel())
# Out:
# RandomForestRegressor()

# %%
moylast5Y = 0
cmp = 0
for r in df_.index:
    if df_.YEAR[r] > (df_.YEAR.max() - 10):
        cmp=cmp+1
        moylast5Y = moylast5Y + df_.Coeff_prod[r]

# %%
moylast5Y = moylast5Y / cmp
moylast5Y
# Out:
# 1.0657424226146162

# %%
estimated_2019 = clf.predict([[2019]])
coeff_prod_2019 = estimated_2019 * moylast5Y

# %%
coeff_prod_2019
# Out:
# array([0.8792375])

# %%
year_inflation = pd.DataFrame(df_.YEAR)
year_inflation["Coef_prod"]=df_.Coeff_prod
#year_inflation["Productivite (kg/ha)"]=df_["Productivite (kg/ha)"]
matrice_corr = year_inflation.corr().round(1)
sns.heatmap(data=matrice_corr, annot=True)

# %% [markdown]
# # REGRESSION

# %%
columnsNamesArr = ['PRECTOT', 'T2M', 'ALLSKY_SFC_SW_DWN', 'T2MDEW', 'T2M_MIN', 'RH2M', 'YEAR', 'Coeff_prod']
df_features = df_[columnsNamesArr]
# définir la variable cible
df_labels = df_[['Productivite (kg/ha)']]

# %% [markdown]
# # TRAIN

# %%
X_train, X_test, y_train, y_test = train_test_split(df_features, df_labels, test_size=0.2, random_state=1)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4172, 8)
# (1043, 8)
# (4172, 1)
# (1043, 1)

# %%
rf = RandomForestRegressor(max_depth=14, n_estimators=157, random_state=1)
rf.fit(X_train, y_train.values.ravel())

train_score = rf.score(X_train, y_train)
print('train score = ',train_score )

ypred = rf.predict(X_test)
mse = mean_squared_error(ypred  , y_test)
rmse_rf_test = np.sqrt(mean_squared_error(ypred,y_test))
print(' Random Forest RMSE = ',rmse_rf_test )

r2_rf = r2_score(y_test, ypred)
print(' Random Forest R2 = ',r2_rf)

ypred = rf.predict(X_train)
mse = mean_squared_error(ypred  , y_train)
rmse_rf_train = np.sqrt(mean_squared_error(ypred,y_train))
print(' Random Forest TRAIN RMSE = ',rmse_rf_train )

#faire un affichage du déroulement
# Out:
# train score =  1.0
#  Random Forest RMSE =  0.0
#  Random Forest R2 =  1.0
#  Random Forest TRAIN RMSE =  0.0

# %%
print('Random Forest Cross-validation scores')
sc_rfc = cross_val_score(rf, X_test, y_test.values.ravel(), cv=5)
print("AUC: %0.2f (+/- %0.2f)" % (sc_rfc.mean(), sc_rfc.std() * 2))
# Out:
# Random Forest Cross-validation scores
# AUC: 1.00 (+/- 0.00)

# %%
#Kfold validation
from sklearn.model_selection import KFold
kf = KFold(n_splits=10)
for train_index, test_index in kf.split(X_scaled):
    #print("TRAIN:", train_index, "TEST:", test_index)
    print("----------------------------------------------")
    X_train, X_test = X_scaled.iloc[train_index], X_scaled.iloc[test_index]
    y_train, y_test = Y_scaled.iloc[train_index], Y_scaled.iloc[test_index]
    rf = RandomForestRegressor(max_depth=8, n_estimators=400, random_state=1)
    rf.fit(X_train, y_train.values.ravel())

    train_score = rf.score(X_train, y_train)
    print('train score = ',train_score )

    ypred = rf.predict(X_test)
    mse = mean_squared_error(ypred  , y_test)
    rmse_rf_test = np.sqrt(mean_squared_error(ypred,y_test))
    #print(' Random Forest RMSE = ',rmse_rf_test )

    r2_rf = r2_score(y_test, ypred)
    print(' Random Forest R2 = ',r2_rf)
# Out:
# ----------------------------------------------
# train score =  0.9995897355163874
#  Random Forest R2 =  -0.6470335032214078
# ----------------------------------------------
# train score =  0.997252317260374
#  Random Forest R2 =  -13.625536914619667
# ----------------------------------------------
# train score =  0.971580336091812
#  Random Forest R2 =  -0.14518979973342305
# ----------------------------------------------
# train score =  0.9968764232327512
#  Random Forest R2 =  0.44874866104542266
# ----------------------------------------------
# train score =  0.9972715772499231
#  Random Forest R2 =  -2.1606296963343734
# ----------------------------------------------
# train score =  0.9858828371259808
#  Random Forest R2 =  -1.145744636331997
# ----------------------------------------------
# train score =  0.9975209744035936
#  Random Forest R2 =  -0.3646025175298915
# ----------------------------------------------
# train score =  0.9976497850596783
#  Random Forest R2 =  -5.421737357937195
# ----------------------------------------------
# train score =  0.9979948719060021
#  Random Forest R2 =  -0.30093082644382285
# ----------------------------------------------
# train score =  0.9981350035485498
#  Random Forest R2 =  -0.47194311619069484

# %%
X_train, X_test, y_train, y_test = train_test_split(df_features, df_labels, test_size=0.2, random_state=1)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4172, 8)
# (1043, 8)
# (4172, 1)
# (1043, 1)

# %%
rf = RandomForestRegressor(max_depth=14, n_estimators=157, random_state=1)
rf.fit(X_train, y_train.values.ravel())

train_score = rf.score(X_train, y_train)
print('train score = ',train_score )

ypred = rf.predict(X_test)
mse = mean_squared_error(ypred  , y_test)
rmse_rf_test = np.sqrt(mean_squared_error(ypred,y_test))
print(' Random Forest RMSE = ',rmse_rf_test )

r2_rf = r2_score(y_test, ypred)
print(' Random Forest R2 = ',r2_rf)

ypred = rf.predict(X_train)
mse = mean_squared_error(ypred  , y_train)
rmse_rf_train = np.sqrt(mean_squared_error(ypred,y_train))
print(' Random Forest TRAIN RMSE = ',rmse_rf_train )
# Out:
# train score =  1.0
#  Random Forest RMSE =  0.0
#  Random Forest R2 =  1.0
#  Random Forest TRAIN RMSE =  0.0

# %%
cmp = X_VAL.index[0]
size = len(X_VAL)
for i in range(cmp, cmp+size):
    X_VAL.at[i, "Coeff_prod"]=coeff_prod_2019
    
X_VAL_Features = X_VAL[columnsNamesArr]


ypred = rf.predict(X_VAL_Features)
print(ypred[0])
print('Erreur:~', 11400 - ypred[0])
# Out:
# 10064.331210191083
# Erreur:~ 1335.6687898089167

# %%
cmp = X_VAL.index[0]
size = len(X_VAL)
for i in range(cmp, cmp+size):
    X_VAL.at[i, "Coeff_prod"]=moylast5Y
    
X_VAL_Features = X_VAL[columnsNamesArr]


ypred = rf.predict(X_VAL_Features)
print(ypred[0])
print('Erreur:~', 11400 - ypred[0])
# Out:
# 11638.853503184713
# Erreur:~ -238.8535031847132

# %%
# 3300 !! 2019 https://cidades.ibge.gov.br/brasil/rs/santa-maria/pesquisa/14/0?ano=2019
